# %% [markdown]
# <a href="https://colab.research.google.com/github/Alanps31/Exe_PythonBrasil/blob/main/EstruturaDeDecisao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 - Faça um Programa que peça dois números e imprima o maior deles.

# %%
num1 = int(input('Informe um numero: '))
num2 = int(input('Informe outro numero: '))

print('O primeiro numero e o maior') if num1 > num2 else print('O segundo numero e o maior')
# Out:
# Informe um numero: 2
# Informe outro numero: 1
# O primeiro numero e o maior

# %% [markdown]
# 2 - Faça um Programa que peça um valor e mostre na tela se o valor é positivo ou negativo.

# %%
num = float(input('insira um numero: '))

print('O número e positivo') if num >= 0 else print('O número e negativo')
# Out:
# insira um numero: 0
# O número e positivo
